# %% [markdown]
# # 🔬 Virtual Screening with Machine Learning
# This notebook demonstrates how to load and evaluate different ML models trained to classify active compounds against gamma-secretase.

# %%
# 📦 Load libraries
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import svm
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.pipeline import Pipeline
from sklearn.neighbors import NeighborhoodComponentsAnalysis, KNeighborsClassifier

# %%
# 📂 Load dataset
df = pd.read_csv('../data/Gama_secretM.csv')
df.head()

# %%
# 🎯 Prepare data
x = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

pca = PCA(n_components=30)
x_pca = pca.fit_transform(x_scaled)

# %%
# 🤖 Train and evaluate a Random Forest
rf = RandomForestClassifier(n_estimators=270, max_depth=29, min_samples_split=2, min_samples_leaf=1)
scores = cross_val_score(rf, x_pca, y, cv=10, scoring='f1_macro')
print(f"Random Forest F1-macro (CV=10): {scores.mean():.4f} ± {scores.std():.4f}")

# %%
# ➕ You can repeat this for other models like:
# - LogisticRegression
# - MLPClassifier
# - SVM
# - GaussianProcessClassifier
# - Pipeline(NCA + KNN)
# See eval_mods.py for parameter examples.

# %% [markdown]
# ## 📌 Conclusion
# Use this notebook to quickly explore or visualize how the machine learning models are performing. You can also plot confusion matrices, ROC curves or feature importances for deeper analysis.
